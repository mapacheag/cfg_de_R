# %%
#paquetes

import pandas as pd
import seaborn as sb 
import numpy as np
import scipy as scipy
import sklearn as sk
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# cargar base de datos

df = pd.read_excel("../bases_de_datos/base_1_suicidio.xlsx")

# %%
# Resumen de datos para orientacion
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# count         309         309         307         307         308         307
# unique         37         223         126         231         224         138
# top         0 a 4           0           0           0           0           0
# freq           17          87         182          77          84         170
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 45  \
# count          307         308         307         307  ...          307
# unique         236         240         140         243  ...          243
# top              0           0           0           0  ...            0
# freq            72          69         168          65  ...           65
#
#         Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49  Unnamed: 50  \
# count           308          307          307          308          307
# ...
